# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
# %matplotlib inline

import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# %% [markdown]
# ## Generate Cities List

# %%
weather_api_key
# Out:
# '3bd431ae25905111a910ab28badb1866'

# %%
# List for holding lat_lngs and cities
lat_lngs = []
cities = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 607

# %%
print(city)
# Out:
# mutis

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# URL for Weather and API
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key
# url = "api.openweathermap.org/data/2.5/weather?q=Dallas&appid=" + weather_api_key
print(url)
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=3bd431ae25905111a910ab28badb1866

# %%
# List of city data
city_data = []

# Print the header of the list
print("Beginning Data Retreival")
print("-------------------------------------------------------")

# Create count variables
record_count = 1
set_count = 1

# Loop cities in list
for i, city in enumerate(cities):
    
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse JSON and retrieve data
        city_weather = requests.get(city_url).json()

        # Parse out the max temp, humidity, and cloudiness
        city_latitude = city_weather["coord"]["lat"]
        city_longitude = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_date = city_weather["dt"]

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_latitude, 
                          "Lng": city_longitude, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is found, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("---------------------------------------------")
print("Data Loading Complete      ")
print("---------------------------------------------")
# Out:
# Beginning Data Retreival
# -------------------------------------------------------
# Processing Record 1 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 2 of Set 1 | sao sebastiao
# Processing Record 3 of Set 1 | grand river south east
# City not found. Skipping...
# Processing Record 4 of Set 1 | noumea
# Processing Record 5 of Set 1 | hilo
# Processing Record 6 of Set 1 | xam nua
# Processing Record 7 of Set 1 | bluff
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | luderitz
# Processing Record 10 of Set 1 | castro
# Processing Record 11 of Set 1 | ilulissat
# Processing Record 12 of Set 1 | punta arenas
# Processing Record 13 of Set 1 | burnie
# Processing Record 14 of Set 1 | hobart
# Processing Record 15 of Set 1 | jamestown
# Processing Record 16 of Set 1 | chokurdakh
# Processing Record 17 of Set 1 | ushuaia
# Processing Record 18 of Set 1 | mataura
# Processing Record 19 of Set 1 | artyk
# City not found. Skipping...
# ...

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Convert array of JSONs into Pandas DataFrame
city_data_pd = pd.DataFrame(city_data)

# Show Record Count
city_data_pd.count()
# Out:
# City          560
# Lat           560
# Lng           560
# Max Temp      560
# Humidity      560
# Cloudiness    560
# Wind Speed    560
# Country       560
# Date          560
# dtype: int64

# %%
# Display the City Data Frame
city_data_pd.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  sao sebastiao -23.76  -45.41     58.87        87         100        9.75
# 1         noumea -22.28  166.46     71.01        88           0        2.24
# 2           hilo  19.73 -155.09     82.40        65          40       10.29
# 3        xam nua  20.42  104.04     67.23        95         100        1.39
# 4          bluff -46.60  168.33     50.00        97          56        5.01
#
#   Country        Date
# 0      BR  1598045528
# 1      NC  1598045404
# 2      US  1598045528
# 3      LA  1598045757
# 4      NZ  1598045757

# %% [markdown]
# ## Inspect the data and remove the cities where the humidity > 100%.
# ----
# Skip this step if there are no cities that have humidity > 100%.

# %%
city_data_pd.describe()
# Out:
#               Lat         Lng    Max Temp    Humidity  Cloudiness  Wind Speed  \
# count  560.000000  560.000000  560.000000  560.000000  560.000000  560.000000
# mean    19.176018   17.836161   68.621821   71.730357   48.026786    7.247107
# std     32.996598   91.210929   14.531005   20.848387   37.883745    4.938444
# min    -54.800000 -179.170000   35.010000    3.000000    0.000000    0.430000
# 25%     -6.940000  -65.712500   57.200000   60.000000    5.000000    3.375000
# 50%     20.915000   22.725000   70.745000   77.000000   44.000000    6.005000
# 75%     47.107500  102.740000   79.632500   88.000000   88.000000    9.695000
# max     78.220000  179.320000  107.600000  100.000000  100.000000   29.970000
#
#                Date
# count  5.600000e+02
# mean   1.598046e+09
# std    6.805996e+01
# min    1.598045e+09
# 25%    1.598046e+09
# 50%    1.598046e+09
# 75%    1.598046e+09
# max    1.598046e+09

# %%
#  Get indices of cities with humidity over 100%.
unclean_city_data = city_data_pd[(city_data_pd["Humidity"] > 100)].index
                                  
unclean_city_data
# Out:
# Int64Index([], dtype='int64')

# %%
# Make a new DataFrame equal to the city data to drop all humidity outliers by index.
# Passing "inplace=False" will make a copy of the city_data DataFrame, which we call "clean_city_data".
clean_city_data = city_data_pd.drop(unclean_city_data, inplace=False)
clean_city_data.head()
# Out:
#             City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0  sao sebastiao -23.76  -45.41     58.87        87         100        9.75
# 1         noumea -22.28  166.46     71.01        88           0        2.24
# 2           hilo  19.73 -155.09     82.40        65          40       10.29
# 3        xam nua  20.42  104.04     67.23        95         100        1.39
# 4          bluff -46.60  168.33     50.00        97          56        5.01
#
#   Country        Date
# 0      BR  1598045528
# 1      NC  1598045404
# 2      US  1598045528
# 3      LA  1598045757
# 4      NZ  1598045757

# %%
# Extract relevant fields from the data frame
lats = clean_city_data["Lat"]
max_temps = clean_city_data["Max Temp"]
humidity = clean_city_data["Humidity"]
cloudiness = clean_city_data["Cloudiness"]
wind_speed = clean_city_data["Wind Speed"]

# Export the City_Data into a csv
clean_city_data.to_csv(output_data_file, index_label="City_ID")

# %% [markdown]
# ## Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# ## Latitude vs. Temperature Plot

# %%
plt.scatter(lats, 
            max_temps,
            edgecolor="cyan", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Max Temperature (%s)" % time.strftime("%x"))
plt.ylabel("Max Temperature (F)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_Temperature.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Humidity Plot

# %%
# Build the scatter plots for latitude vs. humidity
plt.scatter(lats, 
            humidity,
            edgecolor="cyan", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Humidity (%s)" % time.strftime("%x"))
plt.ylabel("Humidity (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_Humidity.png")

# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Cloudiness Plot

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.scatter(lats, 
            cloudiness,
            edgecolor="cyan", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Cloudiness (%s)" % time.strftime("%x"))
plt.ylabel("Cloudiness (%)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_Cloudiness.png")
# Show plot
plt.show()

# %% [markdown]
# ## Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.scatter(lats, 
            wind_speed,
            edgecolor="cyan", linewidths=1, marker="o", 
            alpha=0.8, label="Cities")

# Incorporate the other graph properties
plt.title("City Latitude vs. Wind Speed (%s)" % time.strftime("%x"))
plt.ylabel("Wind Speed (mph)")
plt.xlabel("Latitude")
plt.grid(True)

# Save the figure
plt.savefig("output_data/Latitude_Wind_Speed.png")
# Show plot
plt.show()

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def plot_linear_regression(x_values, y_values, title, text_coordinates):
    
    # Run regresson on southern hemisphere
    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))

    # Plot
    plt.scatter(x_values,y_values, edgecolor="cyan")
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,text_coordinates,fontsize=23,color="red")
    plt.xlabel('Latitude')
    plt.ylabel(title)
    print(f"The r-value is: {rvalue**2}")
    plt.show()

# %%
# Create Northern and Southern Hemisphere DataFrames
northern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] >= 0)]
southern_hemi_df = city_data_pd.loc[(city_data_pd["Lat"] < 0)]

# %%
northern_hemi_df.head()
# Out:
#           City    Lat     Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 2         hilo  19.73 -155.09     82.40        65          40       10.29
# 3      xam nua  20.42  104.04     67.23        95         100        1.39
# 8    ilulissat  69.22  -51.10     51.80        40          62        1.12
# 12   jamestown  42.10  -79.24     79.00        54           1        5.82
# 13  chokurdakh  70.63  147.92     36.54        89          98        8.95
#
#    Country        Date
# 2       US  1598045528
# 3       LA  1598045757
# 8       GL  1598045529
# 12      US  1598045478
# 13      RU  1598045758

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Northern Hemisphere (Max Temp.)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, "Max Temp", (0,40))
# Out:
# The r-value is: 0.4991650700752604

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
# Linear regression on Southern Hemisphere (Max Temp.)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]
plot_linear_regression(x_values, y_values, 'Max Temp', (-55, 85))
# Out:
# The r-value is: 0.5800204204198757

# %% [raw]
# The r values are relatively close to 0.5, indicating a moderate positive correlation.

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere (Humidity)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity",(40,10))
# Out:
# The r-value is: 0.00012690935684950904

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]
plot_linear_regression(x_values, y_values, "Humidity", (-25,10))
# Out:
# The r-value is: 0.0047685732244650844

# %% [raw]
# The r values are very low, indicating a weak to no relation between humidity and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Northern Hemisphere (Cloudiness)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (40,30))
# Out:
# The r-value is: 0.004486194109193534

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
# Southern Hemisphere (Cloudiness)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]
plot_linear_regression(x_values, y_values, "Cloudiness", (-50,80))
# Out:
# The r-value is: 0.02396615522753917

# %% [raw]
# The r values are low, indicating a no to very weak positive relation between cloudiness and latitude.

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Northern Hemisphere (Wind Speed)
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (25,25))
# Out:
# The r-value is: 0.000463216754518488

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
# Souther Hemisphere (Wind Speed)
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]
plot_linear_regression(x_values, y_values, "Wind Speed", (-50,27))
# Out:
# The r-value is: 0.005071634714938713

# %% [raw]
# The r values are very low, indicatin no realtion at all between wind speed and latitude.
